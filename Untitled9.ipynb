# %% [markdown]
# <a href="https://colab.research.google.com/github/krontobi/colab/blob/master/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch==1.1.0 torchvision==0.3.0
# Out:
# ...
#      |████████████████████████████████| 676.9MB 26kB/s
# ...
#      |████████████████████████████████| 2.6MB 31.6MB/s
# ...
#   Found existing installation: torch 1.5.1+cu101
#     Uninstalling torch-1.5.1+cu101:
#       Successfully uninstalled torch-1.5.1+cu101
#   Found existing installation: torchvision 0.6.1+cu101
#     Uninstalling torchvision-0.6.1+cu101:
#       Successfully uninstalled torchvision-0.6.1+cu101
# ...

# %%
# !pip install pillow==6.1
# Out:
# ...
#      |████████████████████████████████| 2.1MB 6.7MB/s
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# ...

# %%
# !pip install scipy==1.2.0
# Out:
# ...
#      |████████████████████████████████| 26.6MB 110kB/s
# ...
# ERROR: umap-learn 0.4.4 has requirement scipy>=1.3.1, but you'll have scipy 1.2.0 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.2.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ...

# %%
# !pip3 install colorama
# !pip3 install pypng
# !pip3 install ninja
# Out:
# ...
#      |████████████████████████████████| 655kB 6.3MB/s
# ...
#   Created wheel for pypng: filename=pypng-0.0.20-cp36-none-any.whl size=67161 sha256=12efda17657d3c6bcfc8713d117caf9b99a6fcb34d059bf9b7418a322d8d7747
#   Stored in directory: /root/.cache/pip/wheels/41/6b/ef/0493b536b6d4722c2ae9486691b1d49b922b9877922beeabb3
# Successfully built pypng
# ...
#      |████████████████████████████████| 112kB 6.5MB/s
# ...

# %%
# !git clone https://github.com/visinf/irr.git
# Out:
# Cloning into 'irr'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 169 (delta 4), reused 11 (delta 3), pack-reused 152
# Receiving objects: 100% (169/169), 185.69 MiB | 13.44 MiB/s, done.
# Resolving deltas: 100% (64/64), done.
# Checking out files: 100% (91/91), done.

# %%
# !cp -r irr/models/correlation_package_cu9/* irr/models/correlation_package

# %%
rm -r irr/models/correlation_package/build/

# %%
! cd irr && bash install.sh
# Out:
# running install
# running bdist_egg
# running egg_info
# writing correlation_cuda.egg-info/PKG-INFO
# writing dependency_links to correlation_cuda.egg-info/dependency_links.txt
# writing top-level names to correlation_cuda.egg-info/top_level.txt
# writing manifest file 'correlation_cuda.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# building 'correlation_cuda' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cd drive/My\ Drive/Scope2 && bash python evaluate.py -f config/evaluation/eval_template_sintel.yaml --save_result_png false --save_result_occ true
# Out:
# 2020-07-06 21:32:39 ==> Commandline Arguments
# 2020-07-06 21:32:39   batch_size: 4
# 2020-07-06 21:32:39   batch_size_val: 5
# 2020-07-06 21:32:39   bilateral_mask: False
# 2020-07-06 21:32:39   checkpoint: checkpoints/Sintel_comb
# 2020-07-06 21:32:39   checkpoint_exclude_params: ['']
# 2020-07-06 21:32:39   checkpoint_include_params: ['*']
# 2020-07-06 21:32:39   checkpoint_mode: resume_from_best
# 2020-07-06 21:32:39   config_file: config/evaluation/eval_template_sintel.yaml
# 2020-07-06 21:32:39   crop_max_ratio: 1
# 2020-07-06 21:32:39   crop_min_ratio: 0.95
# 2020-07-06 21:32:39   cuda: True
# 2020-07-06 21:32:39   devices: 0
# 2020-07-06 21:32:39   dropout: False
# 2020-07-06 21:32:39   eval_train_val: True
# 2020-07-06 21:32:39   evaluation: 1
# 2020-07-06 21:32:39   get_tmp_results:
# 2020-07-06 21:32:39   loss_perc: False
# 2020-07-06 21:32:39   lr_scheduler: None
# 2020-07-06 21:32:39   max_save: -1
# 2020-07-06 21:32:39   min_save: -1
# ...

# %%
# !nvidia-smi
# Out:
# Mon Jul  6 21:18:23 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0    75W / 149W |    352MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
device = torch.device("cuda")
torch.rand(10).to(device)
# Out:
# tensor([0.8282, 0.4017, 0.3229, 0.1141, 0.0069, 0.4475, 0.7375, 0.3876, 0.0653,
#         0.3614], device='cuda:0')

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !cp -r drive/My\ Drive/Scope2/models

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !cp -r irr/models/correlation_package drive/My\ Drive/Scope2/models

# %%
! rm -r drive/My\ Drive/Scope2/models/correlation_package/build
! cd drive/My\ Drive/Scope2/models/correlation_package && python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing correlation_cuda.egg-info/PKG-INFO
# writing dependency_links to correlation_cuda.egg-info/dependency_links.txt
# writing top-level names to correlation_cuda.egg-info/top_level.txt
# writing manifest file 'correlation_cuda.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# building 'correlation_cuda' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# ...

# %%
# !ls /usr/local/
# Out:
# bin	   cuda-10.1  _gcs_config_ops.so  LICENSE.txt  setup.cfg  xgboost
# cuda	   etc	      include		  man	       share
# cuda-10.0  games      lib		  sbin	       src
